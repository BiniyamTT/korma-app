# %%
import json
import requests
import yfinance as yf
from datetime import datetime

# %%
ticker = yf.Ticker("META")

# %%
print(json.dumps(ticker.info, indent=2))
# Out:
# {
#   "address1": "1 Meta Way",
#   "city": "Menlo Park",
#   "state": "CA",
#   "zip": "94025",
#   "country": "United States",
#   "phone": "650 543 4800",
#   "website": "https://investor.atmeta.com",
#   "industry": "Internet Content & Information",
#   "industryKey": "internet-content-information",
#   "industryDisp": "Internet Content & Information",
#   "sector": "Communication Services",
#   "sectorKey": "communication-services",
#   "sectorDisp": "Communication Services",
# ...

# %%
print(ticker.fast_info.last_price)
# Out:
# 480.8399963378906

# %%
print(ticker.analyst_price_targets)
# Out:
# {'current': 480.84, 'high': 730.0, 'low': 483.0, 'mean': 625.4096, 'median': 634.15}

# %%
print(ticker.growth_estimates)
# Out:
#         stockTrend  indexTrend
# period
# 0q          0.2087      0.1505
# +1q         0.1431      0.0674
# 0y          0.1890      0.1093
# +1y         0.1551      0.1456
# LTG            NaN      0.1220
